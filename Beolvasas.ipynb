# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)

dataset = tf.keras.preprocessing.text_dataset_from_directory('C:\DeepSignDB', labels='inferred', label_mode='int',
    class_names=None, batch_size=64, max_length=None, shuffle=True, seed=None,
    validation_split=None, subset=None, follow_links=False)

for data, labels in dataset:
   print(data.shape)  # (64, 200, 200, 3)
   print(data.dtype)  # float32
   print(labels.shape)  # (64,)
   print(labels.dtype)  # int32
# Out:
# TensorFlow version: 2.8.0
# Found 44532 files belonging to 2 classes.
# (64,)
# <dtype: 'string'>
# (64,)
# <dtype: 'int32'>
# (64,)
# <dtype: 'string'>
# (64,)
# <dtype: 'int32'>
# (64,)
# <dtype: 'string'>
# (64,)
# <dtype: 'int32'>
# (64,)
# <dtype: 'string'>
# (64,)
# <dtype: 'int32'>
# (64,)
# <dtype: 'string'>
# (64,)
# <dtype: 'int32'>
# (64,)
# <dtype: 'string'>
# (64,)
# <dtype: 'int32'>
# (64,)
# <dtype: 'string'>
# (64,)
# <dtype: 'int32'>
# (64,)
# <dtype: 'string'>
# (64,)
# <dtype: 'int32'>
# (64,)
# <dtype: 'string'>
# (64,)
# <dtype: 'int32'>
# (64,)
# <dtype: 'string'>
# (64,)
# <dtype: 'int32'>
# (64,)
# <dtype: 'string'>
# (64,)
# <dtype: 'int32'>
# (64,)
# <dtype: 'string'>
# (64,)
# <dtype: 'int32'>
# (64,)
# <dtype: 'string'>
# (64,)
# <dtype: 'int32'>
# (64,)
# <dtype: 'string'>
# (64,)
# <dtype: 'int32'>
# (64,)
# <dtype: 'string'>
# (64,)
# <dtype: 'int32'>
# (64,)
# <dtype: 'string'>
# (64,)
# <dtype: 'int32'>
# (64,)
# <dtype: 'string'>
# (64,)
# ...
