# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
import pandas as pd
import numpy as np
import sys
import os

'''
dataset = tf.keras.preprocessing.text_dataset_from_directory('D:\DeepSignDB\Teszt', labels=None, label_mode=None,
    class_names=None, batch_size=None, max_length=None, shuffle=False, seed=None,
    validation_split=None, subset=None, follow_links=False)
'''

'''
class Signature:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def myfunc(self):
    print("asd")
'''

allFiles=[];
signatureFiles = os.listdir('D:\DeepSignDBPreprocessedVC3/')

for file in signatureFiles:
    print(file)
    dataframe=pd.read_csv('D:\DeepSignDBPreprocessedVC3/'+ file,sep=' ',header=None)
    array=np.array(dataframe)
    allFiles.append(array)

print('Allfiles')
print(allFiles)

'''
dataframe=pd.read_csv('D:\DeepSignDBPreprocessed/u0001_g_0000v00.txt',sep=' ',header=None)
print(dataframe)
array=np.array(dataframe)
column1=array[:, 1]
print(array)
print(column1)
'''
    
'''
with open('readme.txt') as f:
    lines = f.readlines()
splitByLines=lines.splitlines()

splitBySpace=np.array()
for line in splitLines:
    splitBySpace=np.array(line.split(' '))
    splitBySpace.Concatenate(array1)
''' 

'''for data in dataset:
    print(data.shape)  # (64, 200, 200, 3)
    print(data.dtype)  # float32
    print(data)
    
for labels in dataset:
    print(labels.shape)  # (64,)
    print(labels.dtype)  # int32
    
for data, labels in dataset:
    print(data.shape)  # (64, 200, 200, 3)
    print(data.dtype)  # float32
    print(labels.shape)  # (64,)
    print(labels.dtype)  # int32'''
# Out:
# TensorFlow version: 2.8.0
# FingereBioSignDS1Genuineu0384_g_u147_s1_g1_b1_sign_w5_c_001.txt
# FingereBioSignDS1Genuineu0395_g_u158_s1_g1_b1_sign_w5_c_003.txt
# FingereBioSignDS1Genuineu0403_g_u166_s1_g1_b2_sign_w5_c_007.txt
# FingereBioSignDS2Genuineu0426_g_u192_s1_g1_b1_sfin_w6_c_u000_001.txt
# FingereBioSignDS2Genuineu0434_g_u200_s1_g1_b2_sfin_w6_c_u000_005.txt
# StylusBiosecureDS2Genuineu0234_g_u11002s0001_sg3.txt
# StylusBiosecureDS2Genuineu0243_g_u11011s0001_sg1.txt
# StylusBiosecureDS2Genuineu0250_g_u11018s0001_sg4.txt
# StylusBiosecureDS2Genuineu0254_g_u11022s0001_sg1.txt
# StylusBiosecureDS2Genuineu0259_g_u11028s0001_sg2.txt
# StylusBiosecureDS2Genuineu0267_g_u11036s0001_sg1.txt
# StylusBiosecureDS2Genuineu0275_g_u11044s0001_sg3.txt
# StylusBiosecureDS2Genuineu0283_g_u11052s0001_sg2.txt
# StylusBiosecureDS2Genuineu0291_g_u11060s0001_sg4.txt
# StylusBiosecureDS2Genuineu0299_g_u11070s0001_sg3.txt
# StylusBiosecureDS2Genuineu0301_g_u11072s0001_sg4.txt
# ...
